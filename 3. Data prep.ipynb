# %%
import pandas as pd

papers = pd.read_csv('data/papers_topics.csv').iloc[:, 1:]
patents = pd.read_csv('data/patents_topics.csv').iloc[:, 1:]

# %% [markdown]
# ## Subset - Unique topics

# %%
import re

data = papers.sample(5000).copy()

def unique_topics(series):
    t = series.str.strip().str.split(' / ').tolist()
    t = set([x for y in t for x in y])
    print(len(t), 'topics')
    return t

unique_topics(data['topics'])
# Out:
# 245 topics
# {'3d print',
#  '3d printable',
#  '3d printed',
#  '3d printer',
#  '3d printers',
#  '3d printing',
#  '3d prints',
#  'adam',
#  'ai',
#  'artificial intelligence',
#  'artificial intelligent',
#  'attention mechanism',
#  'attention mechanisms',
#  'audio classification',
#  'autoencoder',
#  'automated reasoning',
#  'autonomous car',
#  'autonomous cars',
#  'autonomous vehicle',
#  'auv',
#  'aws',
#  'back propagation',
#  'backpropagation',
#  'bayesian inference',
#  'big data',
#  'boltzmann machine',
#  'boosting algorithm',
#  'cassandra',
#  'chatbot',
#  'chatbots',
#  'classification',
#  'cloud architecture',
#  'cloud architectures',
#  'cloud computer',
#  'cloud computig',
#  'cloud computing',
#  'cloud infrastructure',
#  'cloud infrastructures',
#  'cloud server',
#  'cloud servers',
#  'cloud storage',
#  'cloud technologies',
#  'cloud technology',
#  'cluster computing',
#  'clustering',
#  'cnn',
#  'cnns',
#  'computer vision',
#  'convolutional layers',
#  'convolutional neural network',
#  'convolutional neural networks',
#  'cyber infrastructure',
#  'cyberinfrastructure',
#  'data center',
#  'data centers',
#  'data centre',
#  'data centres',
#  'data intensive computing',
#  'data mining',
#  'data science',
#  'data storage',
#  'database',
#  'dbms',
#  'deep learning',
#  'deep neural network',
#  'deep neural networks',
#  'distributed computing',
#  'dl',
#  'dnn',
#  'docker',
#  'drone',
#  'drones',
#  'dynamic programming',
#  'ec2',
#  'edge computing',
#  'encoder decoder',
#  'ensemble model',
#  'entity recognition',
#  'expert system',
#  'expert systems',
#  'face detection',
#  'factor analysis',
#  'feature engineering',
#  'feature extraction',
#  'feature extractor',
#  'feature extractors',
#  'features engineering',
#  'features extracted',
#  'features extraction',
#  'fog computing',
#  'fully connected layers',
#  'gan',
#  'gans',
#  'gated recurrent unit',
#  'gated recurrent units',
#  'generative adversarial',
#  'genetic algorithm',
#  'genetic algorithms',
#  'gesture recognition',
#  'gradient ascent',
#  'gradient boosting',
#  'gradient descent',
#  'graphic processing unit',
#  'graphic processing units',
#  'graphics processing unit',
#  'graphics processing units',
#  'grid computing',
#  'gru',
#  'hadoop',
#  'hardware accelerated',
#  'hardware acceleration',
#  'hardware accelerator',
#  'hardware accelerators',
#  'hbase',
#  'high performance computing',
#  'hive',
#  'humanoid robot',
#  'humanoid robots',
#  'iaas',
#  'image classification',
#  'image classified',
#  'image classifier',
#  'image classifiers',
#  'image recognition',
#  'image segmentation',
#  'industry 4 0',
#  'information retrieval',
#  'intelligent machines',
#  'kernel machine',
#  'kernel machines',
#  'knowledge representation',
#  'language model',
#  'language modeling',
#  'language modelling',
#  'language models',
#  'large scale data',
#  'long short term memory',
#  'loss function',
#  'loss functions',
#  'lstm',
#  'machine intelligence',
#  'machine learning',
#  'machine translation',
#  'manipulator',
#  'manipulators',
#  'markov chain',
#  'markov chains',
#  'markov decision',
#  'markov process',
#  'massive data',
#  'meta learning',
#  'microsoft azure',
#  'microsoft sql',
#  'ml',
#  'mlp',
#  'mlps',
#  'mobile robot',
#  'mobile robots',
#  'mongodb',
#  'monte carlo',
#  'multi cloud',
#  'multi layer perceptron',
#  'multi layer perceptrons',
#  'multilayer perceptron',
#  'multilayer perceptrons',
#  'mysql',
#  'natural language processing',
#  'nearest neighbour',
#  'nearest neighbours',
#  'neuromorphic computing',
#  'nlp',
#  'nosql',
#  'object detection',
#  'object identification',
#  'object recognition',
#  'on demand computing',
#  'optical computing',
#  'oracle',
#  'paas',
#  'parallel processing',
#  'pattern recognition',
#  'policy gradient',
#  'policy optimization',
#  'pose estimation',
#  'principal component',
#  'q learning',
#  'quantum computation',
#  'quantum computational',
#  'quantum computations',
#  'quantum computed',
#  'quantum computer',
#  'quantum computers',
#  'quantum computing',
#  'random forest',
#  'random forests',
#  'rdbms',
#  'recurrent neural network',
#  'recurrent neural networks',
#  'redis',
#  'regression',
#  'reinforcement learning',
#  'relational database',
#  'robot',
#  'robotic',
#  'robotics',
#  'robots',
#  'saas',
#  'search algorithm',
#  'search algorithms',
#  'search tree',
#  'self driving',
#  'semantic search',
#  'semi supervised learning',
#  'sentiment analysis',
#  'spark',
#  'speech recognition',
#  'sql',
#  'statistical learning',
#  'supercomputer',
#  'supercomputers',
#  'supercomputing',
#  'supervised learning',
#  'support vector',
#  'svm',
#  'text classification',
#  'text to speech',
#  'topic modeling',
#  'topic modelling',
#  'transfer learning',
#  'tree search',
#  'uav',
#  'ugv',
#  'underwater vehicle',
#  'underwater vehicles',
#  'unmanned aerial vehicle',
#  'unmanned aerial vehicles',
#  'unmanned air vehicles',
#  'unmanned aircraft',
#  'unmanned ground vehicle',
#  'unmanned underwater',
#  'unmanned vehicle',
#  'unmanned vehicles',
#  'unsupervised learning',
#  'voice recognition',
#  'word2vec'}

# %% [markdown]
# **Remove plurals**

# %%
def remove_plurals(series):
    return series.str.replace('( \w+)s ', '\g<1> ', regex=True).str.replace(' (\w+)s $', ' \g<1> ', regex=True)

data['topics'] = remove_plurals(data['topics'])
unique_topics(data['topics'])
# Out:
# 199 topics
# {'3d print',
#  '3d printable',
#  '3d printed',
#  '3d printer',
#  '3d printing',
#  'adam',
#  'ai',
#  'artificial intelligence',
#  'artificial intelligent',
#  'attention mechanism',
#  'audio classification',
#  'autoencoder',
#  'automated reasoning',
#  'autonomou car',
#  'autonomou cars',
#  'autonomou vehicle',
#  'auv',
#  'aw',
#  'back propagation',
#  'backpropagation',
#  'bayesian inference',
#  'big data',
#  'boltzmann machine',
#  'boosting algorithm',
#  'cassandra',
#  'chatbot',
#  'classification',
#  'cloud architecture',
#  'cloud computer',
#  'cloud computig',
#  'cloud computing',
#  'cloud infrastructure',
#  'cloud server',
#  'cloud storage',
#  'cloud technologie',
#  'cloud technology',
#  'cluster computing',
#  'clustering',
#  'cnn',
#  'computer vision',
#  'convolutional layer',
#  'convolutional neural network',
#  'cyber infrastructure',
#  'cyberinfrastructure',
#  'data center',
#  'data centre',
#  'data intensive computing',
#  'data mining',
#  'data science',
#  'data storage',
#  'database',
#  'dbm',
#  'deep learning',
#  'deep neural network',
#  'distributed computing',
#  'dl',
#  'dnn',
#  'docker',
#  'drone',
#  'dynamic programming',
#  'ec2',
#  'edge computing',
#  'encoder decoder',
#  'ensemble model',
#  'entity recognition',
#  'expert system',
#  'face detection',
#  'factor analysi',
#  'feature engineering',
#  'feature extracted',
#  'feature extraction',
#  'feature extractor',
#  'fog computing',
#  'fully connected layer',
#  'gan',
#  'gated recurrent unit',
#  'generative adversarial',
#  'genetic algorithm',
#  'gesture recognition',
#  'gradient ascent',
#  'gradient boosting',
#  'gradient descent',
#  'graphic processing unit',
#  'grid computing',
#  'gru',
#  'hadoop',
#  'hardware accelerated',
#  'hardware acceleration',
#  'hardware accelerator',
#  'hbase',
#  'high performance computing',
#  'hive',
#  'humanoid robot',
#  'iaa',
#  'image classification',
#  'image classified',
#  'image classifier',
#  'image recognition',
#  'image segmentation',
#  'industry 4 0',
#  'information retrieval',
#  'intelligent machine',
#  'kernel machine',
#  'knowledge representation',
#  'language model',
#  'language modeling',
#  'language modelling',
#  'large scale data',
#  'long short term memory',
#  'los function',
#  'los functions',
#  'lstm',
#  'machine intelligence',
#  'machine learning',
#  'machine translation',
#  'manipulator',
#  'markov chain',
#  'markov decision',
#  'markov proces',
#  'massive data',
#  'meta learning',
#  'microsoft azure',
#  'microsoft sql',
#  'ml',
#  'mlp',
#  'mobile robot',
#  'mongodb',
#  'monte carlo',
#  'multi cloud',
#  'multi layer perceptron',
#  'multilayer perceptron',
#  'mysql',
#  'natural language processing',
#  'nearest neighbour',
#  'neuromorphic computing',
#  'nlp',
#  'nosql',
#  'object detection',
#  'object identification',
#  'object recognition',
#  'on demand computing',
#  'optical computing',
#  'oracle',
#  'paa',
#  'parallel processing',
#  'pattern recognition',
#  'policy gradient',
#  'policy optimization',
#  'pose estimation',
#  'principal component',
#  'q learning',
#  'quantum computation',
#  'quantum computational',
#  'quantum computed',
#  'quantum computer',
#  'quantum computing',
#  'random forest',
#  'rdbm',
#  'recurrent neural network',
#  'redi',
#  'regression',
#  'reinforcement learning',
#  'relational database',
#  'robot',
#  'robotic',
#  'saa',
#  'search algorithm',
#  'search tree',
#  'self driving',
#  'semantic search',
#  'semi supervised learning',
#  'sentiment analysi',
#  'spark',
#  'speech recognition',
#  'sql',
#  'statistical learning',
#  'supercomputer',
#  'supercomputing',
#  'supervised learning',
#  'support vector',
#  'svm',
#  'text classification',
#  'text to speech',
#  'topic modeling',
#  'topic modelling',
#  'transfer learning',
#  'tree search',
#  'uav',
#  'ugv',
#  'underwater vehicle',
#  'unmanned aerial vehicle',
#  'unmanned air vehicle',
#  'unmanned aircraft',
#  'unmanned ground vehicle',
#  'unmanned underwater',
#  'unmanned vehicle',
#  'unsupervised learning',
#  'voice recognition',
#  'word2vec'}

# %% [markdown]
# **Group related topics**

# %%
def map_topics(series, mapper):
    series = series.str.title()
    for topic, regex in mapper.items():
        series = series.str.replace(regex, topic, regex=True, flags=re.IGNORECASE)
    return series

mapper = {
    "Analysis": "analysi", " Loss ": ' los? ', "Extraction": "extrac\w+", " Modeling ": " model\w* ",
    " SaaS ": " saas? ", " IaaS ": " iaas? ", " PaaS ": " paas? ",
    "Robots": "robots?", "Robotics": "robotics?|robotsics?",
    "Classification": "classif\w+",
    "Redis ": "redi ",
    "3D Print": "3d print\w*",
    "Big": "massive|large scale",
    " AI ": " ai | artificial intellig\w+ | Machine Intelligence | Intelligent Machine ",
    " AUV ": " auv | autonomous underwater vehicle | underwater vehicle | Unmanned Underwater ",
    "Back-propagation": "back propagation|backpropagation",
    " Clouds ": " cloud \w+ | Multi Cloud ",
    "Cluster Computing ": "cluster \w+ ",
    " DBM ": " dbm ",
    " Deep Learning ": " deep learning | dl ",
    " Generative Adversarial Network ": " gans? | generative adversarial networks? | generative adversarial ",
    " GPU ": " gpu | graphics? processing units? ",
    "Hardware Acceleration": "hardware acceler\w+",
    " Machine Learning ": " ml | machine learning ",
    "Markov ": "markov \w+ ",
    " Multi-layer perceptron ": " multi layer perceptrons? | mlp | multilayer perceptron ",
    " NLP ": " natural language processing | nlp ",
    "Nearest Neighbors": "nearest neighbou?rs?",
    "Object Recognition": "object detection|object recognition|object identification",
    "Dimensionality Reduction": 'factor analysis|principal components?',
    "QPU": "quantum processing units?",
    " SVM ": " support vector | svm ",
    " UAM ": " drones? | uav | unmanned aerial vehicle | unmanned aircraft\s?\w* | uas | unmanned air vehicle ",
    " AWS ": " aw ",
    " Optimization Algorithm ": " adam | gradient \w{1,2}scent ",
    "Boosting": "Boosting Algorithm|Gradient Boosting",
    " Convolutional Networks ": " cnns? | Convolutional Layers? | Convolutional Neural Net\w* ",
    "Data Center": "data centre",
    "Deep Learning": "Deep Neural Network|dnn",
    "Text Embedding": "doc2vec|word2vec|seq2seq",
    " RNN ": " gru | lstm | rnn | recurrent neural net\w* | Gated Recurrent Unit | Long Short Term Memory ",
    " UGV ": " ugv | Unmanned Ground Vehicle | Autonomou Vehicle | Self Driving | Autonomou car ",
    " Voice Recognition ": " Voice Activity Detection | text2speech | text to speech | Speech Recognition ",
    " Search Algorithm ": " Tree Search | search trees? ",
#     "Computer Vision": "text\s?to\s?image|Image Classification|Image Recognition|Image Segmentation|Gesture Recognition|",
    " Trees ": " regression trees? | classification trees? | random forests? ",
    "Transformers & Attention": "Attention Mechanisms?|Attention layers?|transformer architectures?|transformer net\\w+",
    "Supercomputers": "Super\s?comput\w+",
    "Quantum Computing": "Quantum Comput\w+",
    "Neuromorphic Computing": "Neuromorphic Comput\w+",
    " Reinforcement Learning ": " rl | q learning | policy gradient | policy optimization ",
    " BD & Cloud Solutions ": " On Demand Computing | hadoop | spark | mysql | cassandra | neo[45]j | mongodb | hive | kafka | ec2 | elasticsearch | bigtable | hbase | oracle | microsoft sql | redis | ibm db2 | microsoft azure | google cloud | sqlite | mariadb | splunk | dynamodb ",
    " NRDBMS & NoSQL ": " nosql | nrdbm?s? | non\s?Relational Database ",
    " RDBMS & SQL ": " rdbm?s? | Relational Database | sql | mysql | sqlite ",
    " Database ": " dbm ",
    "Cyber Infrastructure": "Cyber\s?Infrastructure"
}

data['topics'] = map_topics(data['topics'], mapper)
unique_topics(data['topics'])
# Out:
# 108 topics
# {'3D Print',
#  'AI',
#  'AUV',
#  'AWS',
#  'Audio Classification',
#  'Autoencoder',
#  'Automated Reasoning',
#  'Autonomou Cars',
#  'BD & Cloud Solutions',
#  'Back-propagation',
#  'Bayesian Inference',
#  'Big Data',
#  'Boltzmann Machine',
#  'Boosting',
#  'Chatbot',
#  'Classification',
#  'Clouds',
#  'Cluster Computing',
#  'Clustering',
#  'Computer Vision',
#  'Convolutional Networks',
#  'Cyber Infrastructure',
#  'Data Center',
#  'Data Intensive Computing',
#  'Data Mining',
#  'Data Science',
#  'Data Storage',
#  'Database',
#  'Deep Learning',
#  'Dimensionality Reduction',
#  'Distributed Computing',
#  'Docker',
#  'Dynamic Programming',
#  'Edge Computing',
#  'Encoder Decoder',
#  'Ensemble Modeling',
#  'Entity Recognition',
#  'Expert System',
#  'Face Detection',
#  'Feature Engineering',
#  'Feature Extraction',
#  'Fog Computing',
#  'Fully Connected Layer',
#  'GPU',
#  'Generative Adversarial Network',
#  'Genetic Algorithm',
#  'Gesture Recognition',
#  'Grid Computing',
#  'Hardware Acceleration',
#  'High Performance Computing',
#  'Humanoid Robots',
#  'IaaS',
#  'Image Classification',
#  'Image Recognition',
#  'Image Segmentation',
#  'Industry 4 0',
#  'Information Retrieval',
#  'Kernel Machine',
#  'Knowledge Representation',
#  'Language Modeling',
#  'Loss Function',
#  'Loss Functions',
#  'Machine Learning',
#  'Machine Translation',
#  'Manipulator',
#  'Markov',
#  'Meta Learning',
#  'Mobile Robots',
#  'Monte Carlo',
#  'Multi-layer perceptron',
#  'NLP',
#  'NRDBMS & NoSQL',
#  'Nearest Neighbors',
#  'Neuromorphic Computing',
#  'Object Recognition',
#  'Optical Computing',
#  'Optimization Algorithm',
#  'PaaS',
#  'Parallel Processing',
#  'Pattern Recognition',
#  'Pose Estimation',
#  'Quantum Computing',
#  'RDBMS & SQL',
#  'RNN',
#  'Regression',
#  'Reinforcement Learning',
#  'Robotics',
#  'Robots',
#  'SVM',
#  'SaaS',
#  'Search Algorithm',
#  'Semantic Search',
#  'Semi Supervised Learning',
#  'Sentiment Analysis',
#  'Statistical Learning',
#  'Supercomputers',
#  'Supervised Learning',
#  'Text Classification',
#  'Text Embedding',
#  'Topic Modeling',
#  'Transfer Learning',
#  'Transformers & Attention',
#  'Trees',
#  'UAM',
#  'UGV',
#  'Unmanned Vehicle',
#  'Unsupervised Learning',
#  'Voice Recognition'}

# %%
data.head()
# Out:
#                                        topics  year  \
# 214505   Loss Function / Pattern Recognition   2009
# 81548                                     AI   2015
# 215248                 Information Retrieval   2009
# 144403         Regression / Machine Learning   2018
# 176881                   Pattern Recognition   2006
#
#                                                        AU  \
# 214505                         Rafajlowicz, E; Krzyzak, A
# 81548                                         Broekens, J
# 215248                         Geldart, J; Song, W; Li, Y
# 144403                        Badii, C; Nesi, P; Paoli, I
# 176881  Parra, V; Arrieta, AA; Fernandez-Escudero, JA;...
#
#                                                 publisher  \
# 214505   NONLINEAR ANALYSIS-THEORY METHODS & APPLICATIONS
# 81548   2015 INTERNATIONAL CONFERENCE ON AFFECTIVE COM...
# 215248  2009 IEEE 33RD INTERNATIONAL COMPUTER SOFTWARE...
# 144403                                        IEEE ACCESS
# 176881                   SENSORS AND ACTUATORS B-CHEMICAL
#
#                                            research_areas  n_refs  \
# 214505                                        Mathematics      22
# 81548                       Computer Science; Engineering      13
# 215248                                   Computer Science       7
# 144403  Computer Science; Engineering; Telecommunications      47
# 176881  Chemistry; Electrochemistry; Instruments & Ins...      23
#
#         n_citations  n_authors  n_affils  n_grants
# 214505            5          2         2         2
# 81548             1          1         1         0
# 215248            0          3         2         0
# 144403            5          3         1         2
# 176881           89          5         0         0

# %% [markdown]
# ## Whole data
#
# **Science**

# %%
papers2 = papers.copy()
unique_topics(papers2['topics'])
# Out:
# 377 topics
# {'3d print',
#  '3d printability',
#  '3d printable',
#  '3d printablility',
#  '3d printed',
#  '3d printer',
#  '3d printers',
#  '3d printhead',
#  '3d printing',
#  '3d printings',
#  '3d printinng',
#  '3d printinted',
#  '3d printouts',
#  '3d prints',
#  'adam',
#  'ai',
#  'artificial intelligecet',
#  'artificial intelligence',
#  'artificial intelligencegreenhouse',
#  'artificial intelligences',
#  'artificial intelligent',
#  'attention layer',
#  'attention layers',
#  'attention mechanism',
#  'attention mechanisms',
#  'audio classification',
#  'auto encoder',
#  'autoencoder',
#  'automated question answering',
#  'automated reasoning',
#  'autonomous car',
#  'autonomous cars',
#  'autonomous vehicle',
#  'auv',
#  'aws',
#  'back propagation',
#  'backpropagation',
#  'bayesian inference',
#  'bayesian machine learning',
#  'bert',
#  'big data',
#  'bigtable',
#  'boltzmann machine',
#  'boosting algorithm',
#  'boosting algorithms',
#  'cassandra',
#  'chatbot',
#  'chatbots',
#  'classification',
#  'cloud architecture',
#  'cloud architectures',
#  'cloud client',
#  'cloud clients',
#  'cloud computation',
#  'cloud computational',
#  'cloud computations',
#  'cloud compute',
#  'cloud computed',
#  'cloud computer',
#  'cloud computers',
#  'cloud computes',
#  'cloud computig',
#  'cloud computing',
#  'cloud computingis',
#  'cloud computingprocessor',
#  'cloud compututing',
#  'cloud infrastructure',
#  'cloud infrastructures',
#  'cloud server',
#  'cloud servers',
#  'cloud storage',
#  'cloud technological',
#  'cloud technologies',
#  'cloud technology',
#  'cluster computation',
#  'cluster computational',
#  'cluster computations',
#  'cluster compute',
#  'cluster computer',
#  'cluster computers',
#  'cluster computing',
#  'clustering',
#  'cnn',
#  'cnns',
#  'computer vision',
#  'convolutional layer',
#  'convolutional layers',
#  'convolutional neural netowrks',
#  'convolutional neural nets',
#  'convolutional neural netwoks',
#  'convolutional neural network',
#  'convolutional neural networking',
#  'convolutional neural networks',
#  'cyber infrastructure',
#  'cyberinfrastructure',
#  'data center',
#  'data centers',
#  'data centre',
#  'data centres',
#  'data intensive computing',
#  'data mining',
#  'data science',
#  'data sciences',
#  'data storage',
#  'database',
#  'dbms',
#  'decentralized computing',
#  'deep learning',
#  'deep neural netorks',
#  'deep neural nets',
#  'deep neural network',
#  'deep neural networkbased',
#  'deep neural networks',
#  'dew computing',
#  'distributed computing',
#  'distributed file system',
#  'distributed file systems',
#  'dl',
#  'dnn',
#  'doc2vec',
#  'docker',
#  'drone',
#  'drones',
#  'dynamic cloud',
#  'dynamic clouds',
#  'dynamic programming',
#  'dynamodb',
#  'ec2',
#  'edge computing',
#  'elasticsearch',
#  'encoder decoder',
#  'ensemble model',
#  'entity recognition',
#  'expert system',
#  'expert systems',
#  'face detection',
#  'factor analysis',
#  'feature engineering',
#  'feature extracted',
#  'feature extracting',
#  'feature extractio',
#  'feature extraction',
#  'feature extractioni',
#  'feature extractionmethods',
#  'feature extractions',
#  'feature extractiou',
#  'feature extractive',
#  'feature extractor',
#  'feature extractors',
#  'features engineering',
#  'features extracted',
#  'features extracting',
#  'features extraction',
#  'features extractor',
#  'features extractors',
#  'features extracts',
#  'fog computing',
#  'fully connected layer',
#  'fully connected layers',
#  'gan',
#  'gans',
#  'gated recurrent unit',
#  'gated recurrent units',
#  'generative adversarial',
#  'genetic algorithm',
#  'genetic algorithms',
#  'gesture recognition',
#  'google cloud',
#  'gradient ascent',
#  'gradient boosting',
#  'gradient descent',
#  'graphic processing unit',
#  'graphic processing units',
#  'graphics processing unit',
#  'graphics processing units',
#  'grid computing',
#  'gru',
#  'hadoop',
#  'hardware accelerate',
#  'hardware accelerated',
#  'hardware accelerates',
#  'hardware acceleration',
#  'hardware accelerations',
#  'hardware accelerator',
#  'hardware accelerators',
#  'hbase',
#  'high performance computing',
#  'hive',
#  'humanoid robot',
#  'humanoid robots',
#  'iaas',
#  'ibm db2',
#  'image classification',
#  'image classifications',
#  'image classified',
#  'image classifier',
#  'image classifiers',
#  'image recognition',
#  'image segmentation',
#  'image to text',
#  'industry 4 0',
#  'information retrieval',
#  'intelligent machine',
#  'intelligent machines',
#  'inter cloud computing',
#  'kafka',
#  'kernel machine',
#  'kernel machines',
#  'knowledge representation',
#  'knowledge representations',
#  'language model',
#  'language modelica',
#  'language modeling',
#  'language modelling',
#  'language models',
#  'large scale data',
#  'long short term memory',
#  'loss function',
#  'loss functions',
#  'lstm',
#  'machine intelligence',
#  'machine learning',
#  'machine translation',
#  'manipulator',
#  'manipulators',
#  'mariadb',
#  'markov chain',
#  'markov chains',
#  'markov decision',
#  'markov decisions',
#  'markov process',
#  'markov processes',
#  'massive data',
#  'meta learning',
#  'microsoft azure',
#  'microsoft sql',
#  'ml',
#  'mlp',
#  'mlps',
#  'mobile robot',
#  'mobile robots',
#  'mongodb',
#  'monte carlo',
#  'multi cloud',
#  'multi layer perceptron',
#  'multi layer perceptrons',
#  'multi processing',
#  'multilayer perceptron',
#  'multilayer perceptrons',
#  'multiprocessing',
#  'mysql',
#  'natural language processing',
#  'nearest neighbour',
#  'nearest neighbours',
#  'neo4j',
#  'neuromorphic computation',
#  'neuromorphic computational',
#  'neuromorphic computations',
#  'neuromorphic computer',
#  'neuromorphic computers',
#  'neuromorphic computing',
#  'nlp',
#  'non relational database',
#  'nosql',
#  'object detection',
#  'object identification',
#  'object recognition',
#  'on demand computing',
#  'optical computing',
#  'oracle',
#  'paas',
#  'parallel processing',
#  'pattern recognition',
#  'photonic computing',
#  'policy gradient',
#  'policy optimization',
#  'pose estimation',
#  'principal component',
#  'q learning',
#  'quantum computable',
#  'quantum computater',
#  'quantum computation',
#  'quantum computational',
#  'quantum computationally',
#  'quantum computations',
#  'quantum compute',
#  'quantum computed',
#  'quantum computer',
#  'quantum computers',
#  'quantum computes',
#  'quantum computin',
#  'quantum computing',
#  'quantum computingl',
#  'random forest',
#  'random forests',
#  'rdbms',
#  'recurrent neural nets',
#  'recurrent neural netwok',
#  'recurrent neural network',
#  'recurrent neural networkks',
#  'recurrent neural networks',
#  'redis',
#  'regression',
#  'reinforcement learning',
#  'relational database',
#  'robot',
#  'robotic',
#  'robotics',
#  'robots',
#  'saas',
#  'search algorithm',
#  'search algorithms',
#  'search tree',
#  'self driving',
#  'self supervised learning',
#  'semantic search',
#  'semi supervised learning',
#  'sentence similarity',
#  'sentiment analysis',
#  'seq2seq',
#  'spark',
#  'speech recognition',
#  'splunk',
#  'sql',
#  'sqlite',
#  'statistical learning',
#  'super computation',
#  'super computer',
#  'super computers',
#  'super computing',
#  'supercomputacion',
#  'supercomputation',
#  'supercomputations',
#  'supercompute',
#  'supercomputer',
#  'supercomputerbluegene',
#  'supercomputerl',
#  'supercomputeron',
#  'supercomputers',
#  'supercomputing',
#  'supervised learning',
#  'support vector',
#  'svm',
#  'tensor processing unit',
#  'tensor processing units',
#  'text classification',
#  'text generation',
#  'text similarity',
#  'text to image',
#  'text to speech',
#  'token classification',
#  'topic modeling',
#  'topic modelling',
#  'transfer learning',
#  'transformer architecture',
#  'transformer architectures',
#  'transformer network',
#  'transformer networks',
#  'tree search',
#  'uav',
#  'ugv',
#  'underwater vehicle',
#  'underwater vehicles',
#  'unmanned aerial vehicle',
#  'unmanned aerial vehicles',
#  'unmanned air vehicle',
#  'unmanned air vehicles',
#  'unmanned aircraft',
#  'unmanned ground vehicle',
#  'unmanned spacecraft',
#  'unmanned underwater',
#  'unmanned vehicle',
#  'unmanned vehicles',
#  'unsupervised learning',
#  'voice activity detection',
#  'voice recognition',
#  'word2vec'}

# %%
papers2['topics'] = remove_plurals(papers2['topics'])
unique_topics(papers2['topics'])
# Out:
# 297 topics
# {'3d print',
#  '3d printability',
#  '3d printable',
#  '3d printablility',
#  '3d printed',
#  '3d printer',
#  '3d printhead',
#  '3d printing',
#  '3d printinng',
#  '3d printinted',
#  '3d printout',
#  'adam',
#  'ai',
#  'artificial intelligecet',
#  'artificial intelligence',
#  'artificial intelligencegreenhouse',
#  'artificial intelligent',
#  'attention layer',
#  'attention mechanism',
#  'audio classification',
#  'auto encoder',
#  'autoencoder',
#  'automated question answering',
#  'automated reasoning',
#  'autonomou car',
#  'autonomou cars',
#  'autonomou vehicle',
#  'auv',
#  'aw',
#  'back propagation',
#  'backpropagation',
#  'bayesian inference',
#  'bayesian machine learning',
#  'bert',
#  'big data',
#  'bigtable',
#  'boltzmann machine',
#  'boosting algorithm',
#  'cassandra',
#  'chatbot',
#  'classification',
#  'cloud architecture',
#  'cloud client',
#  'cloud computation',
#  'cloud computational',
#  'cloud compute',
#  'cloud computed',
#  'cloud computer',
#  'cloud computig',
#  'cloud computing',
#  'cloud computingi',
#  'cloud computingprocessor',
#  'cloud compututing',
#  'cloud infrastructure',
#  'cloud server',
#  'cloud storage',
#  'cloud technological',
#  'cloud technologie',
#  'cloud technology',
#  'cluster computation',
#  'cluster computational',
#  'cluster compute',
#  'cluster computer',
#  'cluster computing',
#  'clustering',
#  'cnn',
#  'computer vision',
#  'convolutional layer',
#  'convolutional neural net',
#  'convolutional neural netowrk',
#  'convolutional neural netwok',
#  'convolutional neural network',
#  'convolutional neural networking',
#  'cyber infrastructure',
#  'cyberinfrastructure',
#  'data center',
#  'data centre',
#  'data intensive computing',
#  'data mining',
#  'data science',
#  'data storage',
#  'database',
#  'dbm',
#  'decentralized computing',
#  'deep learning',
#  'deep neural net',
#  'deep neural netork',
#  'deep neural network',
#  'deep neural networkbased',
#  'dew computing',
#  'distributed computing',
#  'distributed file system',
#  'dl',
#  'dnn',
#  'doc2vec',
#  'docker',
#  'drone',
#  'dynamic cloud',
#  'dynamic programming',
#  'dynamodb',
#  'ec2',
#  'edge computing',
#  'elasticsearch',
#  'encoder decoder',
#  'ensemble model',
#  'entity recognition',
#  'expert system',
#  'face detection',
#  'factor analysi',
#  'feature engineering',
#  'feature extract',
#  'feature extracted',
#  'feature extracting',
#  'feature extractio',
#  'feature extraction',
#  'feature extractioni',
#  'feature extractionmethod',
#  'feature extractiou',
#  'feature extractive',
#  'feature extractor',
#  'fog computing',
#  'fully connected layer',
#  'gan',
#  'gated recurrent unit',
#  'generative adversarial',
#  'genetic algorithm',
#  'gesture recognition',
#  'google cloud',
#  'gradient ascent',
#  'gradient boosting',
#  'gradient descent',
#  'graphic processing unit',
#  'grid computing',
#  'gru',
#  'hadoop',
#  'hardware accelerate',
#  'hardware accelerated',
#  'hardware acceleration',
#  'hardware accelerator',
#  'hbase',
#  'high performance computing',
#  'hive',
#  'humanoid robot',
#  'iaa',
#  'ibm db2',
#  'image classification',
#  'image classified',
#  'image classifier',
#  'image recognition',
#  'image segmentation',
#  'image to text',
#  'industry 4 0',
#  'information retrieval',
#  'intelligent machine',
#  'inter cloud computing',
#  'kafka',
#  'kernel machine',
#  'knowledge representation',
#  'language model',
#  'language modelica',
#  'language modeling',
#  'language modelling',
#  'large scale data',
#  'long short term memory',
#  'los function',
#  'los functions',
#  'lstm',
#  'machine intelligence',
#  'machine learning',
#  'machine translation',
#  'manipulator',
#  'mariadb',
#  'markov chain',
#  'markov decision',
#  'markov proce',
#  'markov proces',
#  'markov processe',
#  'massive data',
#  'meta learning',
#  'microsoft azure',
#  'microsoft sql',
#  'ml',
#  'mlp',
#  'mobile robot',
#  'mongodb',
#  'monte carlo',
#  'multi cloud',
#  'multi layer perceptron',
#  'multi processing',
#  'multilayer perceptron',
#  'multiprocessing',
#  'mysql',
#  'natural language processing',
#  'nearest neighbour',
#  'neo4j',
#  'neuromorphic computation',
#  'neuromorphic computational',
#  'neuromorphic computer',
#  'neuromorphic computing',
#  'nlp',
#  'non relational database',
#  'nosql',
#  'object detection',
#  'object identification',
#  'object recognition',
#  'on demand computing',
#  'optical computing',
#  'oracle',
#  'paa',
#  'parallel processing',
#  'pattern recognition',
#  'photonic computing',
#  'policy gradient',
#  'policy optimization',
#  'pose estimation',
#  'principal component',
#  'q learning',
#  'quantum computable',
#  'quantum computater',
#  'quantum computation',
#  'quantum computational',
#  'quantum computationally',
#  'quantum compute',
#  'quantum computed',
#  'quantum computer',
#  'quantum computin',
#  'quantum computing',
#  'quantum computingl',
#  'random forest',
#  'rdbm',
#  'recurrent neural net',
#  'recurrent neural netwok',
#  'recurrent neural network',
#  'recurrent neural networkk',
#  'redi',
#  'regression',
#  'reinforcement learning',
#  'relational database',
#  'robot',
#  'robotic',
#  'saa',
#  'search algorithm',
#  'search tree',
#  'self driving',
#  'self supervised learning',
#  'semantic search',
#  'semi supervised learning',
#  'sentence similarity',
#  'sentiment analysi',
#  'seq2seq',
#  'spark',
#  'speech recognition',
#  'splunk',
#  'sql',
#  'sqlite',
#  'statistical learning',
#  'super computation',
#  'super computer',
#  'super computing',
#  'supercomputacion',
#  'supercomputation',
#  'supercompute',
#  'supercomputer',
#  'supercomputerbluegene',
#  'supercomputerl',
#  'supercomputeron',
#  'supercomputing',
#  'supervised learning',
#  'support vector',
#  'svm',
#  'tensor processing unit',
#  'text classification',
#  'text generation',
#  'text similarity',
#  'text to image',
#  'text to speech',
#  'token classification',
#  'topic modeling',
#  'topic modelling',
#  'transfer learning',
#  'transformer architecture',
#  'transformer network',
#  'tree search',
#  'uav',
#  'ugv',
#  'underwater vehicle',
#  'unmanned aerial vehicle',
#  'unmanned air vehicle',
#  'unmanned aircraft',
#  'unmanned ground vehicle',
#  'unmanned spacecraft',
#  'unmanned underwater',
#  'unmanned vehicle',
#  'unsupervised learning',
#  'voice activity detection',
#  'voice recognition',
#  'word2vec'}

# %%
papers2['topics'] = map_topics(papers2['topics'], mapper)
unique_topics(papers2['topics'])
# Out:
# 132 topics
# {'3D Print',
#  'AI',
#  'AUV',
#  'AWS',
#  'Audio Classification',
#  'Auto Encoder',
#  'Autoencoder',
#  'Automated Question Answering',
#  'Automated Reasoning',
#  'Autonomou Cars',
#  'BD & Cloud Solutions',
#  'Back-propagation',
#  'Bayesian Inference',
#  'Bayesian Machine Learning',
#  'Bert',
#  'Big Data',
#  'Boltzmann Machine',
#  'Boosting',
#  'Chatbot',
#  'Classification',
#  'Clouds',
#  'Cluster Computing',
#  'Clustering',
#  'Computer Vision',
#  'Convolutional Networks',
#  'Cyber Infrastructure',
#  'Data Center',
#  'Data Intensive Computing',
#  'Data Mining',
#  'Data Science',
#  'Data Storage',
#  'Database',
#  'Decentralized Computing',
#  'Deep Learning',
#  'Deep Learningbased',
#  'Deep Neural Net',
#  'Deep Neural Netork',
#  'Dew Computing',
#  'Dimensionality Reduction',
#  'Distributed Computing',
#  'Distributed File System',
#  'Docker',
#  'Dynamic Cloud',
#  'Dynamic Programming',
#  'Edge Computing',
#  'Encoder Decoder',
#  'Ensemble Modeling',
#  'Entity Recognition',
#  'Expert System',
#  'Face Detection',
#  'Feature Engineering',
#  'Feature Extraction',
#  'Fog Computing',
#  'Fully Connected Layer',
#  'GPU',
#  'Generative Adversarial Network',
#  'Genetic Algorithm',
#  'Gesture Recognition',
#  'Grid Computing',
#  'Hardware Acceleration',
#  'High Performance Computing',
#  'Humanoid Robots',
#  'IaaS',
#  'Image Classification',
#  'Image Recognition',
#  'Image Segmentation',
#  'Image To Text',
#  'Industry 4 0',
#  'Information Retrieval',
#  'Inter Clouds',
#  'Kernel Machine',
#  'Knowledge Representation',
#  'Language Modeling',
#  'Loss Function',
#  'Loss Functions',
#  'Machine Learning',
#  'Machine Translation',
#  'Manipulator',
#  'Markov',
#  'Meta Learning',
#  'Mobile Robots',
#  'Monte Carlo',
#  'Multi Processing',
#  'Multi-layer perceptron',
#  'Multiprocessing',
#  'NLP',
#  'NRDBMS & NoSQL',
#  'Nearest Neighbors',
#  'Neuromorphic Computing',
#  'Object Recognition',
#  'Optical Computing',
#  'Optimization Algorithm',
#  'PaaS',
#  'Parallel Processing',
#  'Pattern Recognition',
#  'Photonic Computing',
#  'Pose Estimation',
#  'Quantum Computing',
#  'RDBMS & SQL',
#  'RNN',
#  'Regression',
#  'Reinforcement Learning',
#  'Robotics',
#  'Robots',
#  'SVM',
#  'SaaS',
#  'Search Algorithm',
#  'Self Supervised Learning',
#  'Semantic Search',
#  'Semi Supervised Learning',
#  'Sentence Similarity',
#  'Sentiment Analysis',
#  'Statistical Learning',
#  'Supercomputers',
#  'Supervised Learning',
#  'Tensor Processing Unit',
#  'Text Classification',
#  'Text Embedding',
#  'Text Generation',
#  'Text Similarity',
#  'Text To Image',
#  'Token Classification',
#  'Topic Modeling',
#  'Transfer Learning',
#  'Transformers & Attention',
#  'Trees',
#  'UAM',
#  'UGV',
#  'Unmanned Spacecraft',
#  'Unmanned Vehicle',
#  'Unsupervised Learning',
#  'Voice Recognition'}

# %%
papers2.to_csv('data/papers_topics2.csv', index=False)
papers2.head()
# Out:
#                topics  year  \
# 0        Monte Carlo   2018
# 1   Search Algorithm   2018
# 2             Clouds   2018
# 3             Clouds   2018
# 4     Edge Computing   2018
#
#                                                   AU  \
# 0      Rastegarfar, H; Svensson, T; Peyghambarian, N
# 1  Ali, M; Qaisar, S; Naeem, M; Rodrigues, JJPC; ...
# 2               Liu, JY; Yang, QH; Simon, G; Cui, WL
# 3                                          Leiter, A
# 4  Bruschi, R; Davoli, F; Lago, P; Lombardo, C; P...
#
#                                            publisher  \
# 0   JOURNAL OF OPTICAL COMMUNICATIONS AND NETWORKING
# 1  TRANSACTIONS ON EMERGING TELECOMMUNICATIONS TE...
# 2  IEEE TRANSACTIONS ON NETWORK AND SERVICE MANAG...
# 3  2018 INTERNATIONAL SYMPOSIUM ON NETWORKS, COMP...
# 4  2018 IEEE CONFERENCE ON NETWORK FUNCTION VIRTU...
#
#                                  research_areas  n_refs  n_citations  \
# 0  Computer Science; Optics; Telecommunications      46            1
# 1                            Telecommunications      42            8
# 2                              Computer Science      30            2
# 3          Computer Science; Telecommunications       0            0
# 4                 Computer Science; Engineering      12            0
#
#    n_authors  n_affils  n_grants
# 0          3         2         1
# 1          5         7         2
# 2          4         3         2
# 3          1         1         0
# 4          5         2         0

# %% [markdown]
# **Industry**

# %%
patents2 = patents.copy()
unique_topics(patents2['topics'])
# Out:
# 225 topics
# {'3d print',
#  '3d printable',
#  '3d printed',
#  '3d printer',
#  '3d printers',
#  '3d printhead',
#  '3d printing',
#  '3d printout',
#  'ai',
#  'artificial intelligence',
#  'artificial intelligent',
#  'attention layer',
#  'attention mechanism',
#  'attention mechanisms',
#  'audio classification',
#  'auto encoder',
#  'autoencoder',
#  'automated reasoning',
#  'autonomous car',
#  'autonomous cars',
#  'autonomous vehicle',
#  'auv',
#  'aws',
#  'back propagation',
#  'backpropagation',
#  'bayesian inference',
#  'big data',
#  'boltzmann machine',
#  'boosting algorithm',
#  'chatbot',
#  'chatbots',
#  'classification',
#  'cloud architecture',
#  'cloud client',
#  'cloud clients',
#  'cloud compute',
#  'cloud computer',
#  'cloud computing',
#  'cloud computuing',
#  'cloud infrastructure',
#  'cloud infrastructures',
#  'cloud server',
#  'cloud servers',
#  'cloud storage',
#  'cloud technology',
#  'cluster computing',
#  'clustering',
#  'cnn',
#  'cnns',
#  'computer vision',
#  'convolutional layer',
#  'convolutional layers',
#  'convolutional neural network',
#  'convolutional neural networks',
#  'data center',
#  'data centers',
#  'data centre',
#  'data centres',
#  'data mining',
#  'data science',
#  'data storage',
#  'database',
#  'dbms',
#  'deep learning',
#  'deep neural network',
#  'deep neural networks',
#  'distributed computing',
#  'distributed file system',
#  'dl',
#  'dnn',
#  'drone',
#  'drones',
#  'dynamic cloud',
#  'dynamic programming',
#  'ec2',
#  'edge computing',
#  'encoder decoder',
#  'entity recognition',
#  'expert system',
#  'expert systems',
#  'face detection',
#  'factor analysis',
#  'feature engineering',
#  'feature extracted',
#  'feature extracting',
#  'feature extraction',
#  'feature extractor',
#  'feature extractors',
#  'features extracted',
#  'features extraction',
#  'fog computing',
#  'fully connected layer',
#  'fully connected layers',
#  'gan',
#  'gans',
#  'generative adversarial',
#  'genetic algorithm',
#  'gesture recognition',
#  'gradient descent',
#  'graphics processing unit',
#  'gru',
#  'hadoop',
#  'hardware accelerated',
#  'hardware acceleration',
#  'hardware accelerator',
#  'hardware accelerators',
#  'high performance computing',
#  'hive',
#  'humanoid robot',
#  'humanoid robots',
#  'iaas',
#  'image classification',
#  'image classifications',
#  'image classifier',
#  'image classifying',
#  'image recognition',
#  'image segmentation',
#  'information retrieval',
#  'intelligent machine',
#  'intelligent machines',
#  'knowledge representation',
#  'knowledge representations',
#  'language model',
#  'language modeling',
#  'language models',
#  'large scale data',
#  'long short term memory',
#  'loss function',
#  'loss functions',
#  'lstm',
#  'machine intelligence',
#  'machine learning',
#  'machine translation',
#  'manipulator',
#  'manipulators',
#  'markov decision',
#  'markov process',
#  'massive data',
#  'meta learning',
#  'microsoft azure',
#  'ml',
#  'mlp',
#  'mobile robot',
#  'mobile robots',
#  'monte carlo',
#  'multi cloud',
#  'multilayer perceptron',
#  'natural language processing',
#  'nearest neighbour',
#  'nearest neighbours',
#  'neuromorphic computation',
#  'neuromorphic computer',
#  'neuromorphic computers',
#  'neuromorphic computing',
#  'nlp',
#  'non relational database',
#  'nosql',
#  'object detection',
#  'object identification',
#  'object recognition',
#  'on demand computing',
#  'optical computing',
#  'oracle',
#  'paas',
#  'parallel processing',
#  'pattern recognition',
#  'policy gradient',
#  'pose estimation',
#  'principal component',
#  'q learning',
#  'quantum computation',
#  'quantum computations',
#  'quantum computer',
#  'quantum computers',
#  'quantum computing',
#  'random forest',
#  'recurrent neural network',
#  'recurrent neural networks',
#  'regression',
#  'reinforcement learning',
#  'relational database',
#  'robot',
#  'robotic',
#  'robotics',
#  'robots',
#  'saas',
#  'search algorithm',
#  'search tree',
#  'self driving',
#  'semantic search',
#  'semi supervised learning',
#  'sentiment analysis',
#  'seq2seq',
#  'spark',
#  'speech recognition',
#  'sql',
#  'statistical learning',
#  'supercomputer',
#  'supercomputers',
#  'supervised learning',
#  'support vector',
#  'svm',
#  'text classification',
#  'text to speech',
#  'topic modeling',
#  'transfer learning',
#  'transformer network',
#  'transformer networks',
#  'uav',
#  'ugv',
#  'underwater vehicle',
#  'underwater vehicles',
#  'unmanned aerial vehicle',
#  'unmanned aerial vehicles',
#  'unmanned air vehicle',
#  'unmanned air vehicles',
#  'unmanned aircraft',
#  'unmanned ground vehicle',
#  'unmanned underwater',
#  'unmanned vehicle',
#  'unmanned vehicles',
#  'unsupervised learning',
#  'voice activity detection',
#  'voice recognition',
#  'word2vec'}

# %%
patents2['topics'] = remove_plurals(patents2['topics'])
unique_topics(patents2['topics'])
# Out:
# 184 topics
# {'3d print',
#  '3d printable',
#  '3d printed',
#  '3d printer',
#  '3d printhead',
#  '3d printing',
#  '3d printout',
#  'ai',
#  'artificial intelligence',
#  'artificial intelligent',
#  'attention layer',
#  'attention mechanism',
#  'audio classification',
#  'auto encoder',
#  'autoencoder',
#  'automated reasoning',
#  'autonomou car',
#  'autonomou vehicle',
#  'auv',
#  'aw',
#  'back propagation',
#  'backpropagation',
#  'bayesian inference',
#  'big data',
#  'boltzmann machine',
#  'boosting algorithm',
#  'chatbot',
#  'classification',
#  'cloud architecture',
#  'cloud client',
#  'cloud compute',
#  'cloud computer',
#  'cloud computing',
#  'cloud computuing',
#  'cloud infrastructure',
#  'cloud server',
#  'cloud storage',
#  'cloud technology',
#  'cluster computing',
#  'clustering',
#  'cnn',
#  'computer vision',
#  'convolutional layer',
#  'convolutional neural network',
#  'data center',
#  'data centre',
#  'data mining',
#  'data science',
#  'data storage',
#  'database',
#  'dbm',
#  'deep learning',
#  'deep neural network',
#  'distributed computing',
#  'distributed file system',
#  'dl',
#  'dnn',
#  'drone',
#  'dynamic cloud',
#  'dynamic programming',
#  'ec2',
#  'edge computing',
#  'encoder decoder',
#  'entity recognition',
#  'expert system',
#  'face detection',
#  'factor analysi',
#  'feature engineering',
#  'feature extracted',
#  'feature extracting',
#  'feature extraction',
#  'feature extractor',
#  'fog computing',
#  'fully connected layer',
#  'gan',
#  'generative adversarial',
#  'genetic algorithm',
#  'gesture recognition',
#  'gradient descent',
#  'graphic processing unit',
#  'gru',
#  'hadoop',
#  'hardware accelerated',
#  'hardware acceleration',
#  'hardware accelerator',
#  'high performance computing',
#  'hive',
#  'humanoid robot',
#  'iaa',
#  'image classification',
#  'image classifier',
#  'image classifying',
#  'image recognition',
#  'image segmentation',
#  'information retrieval',
#  'intelligent machine',
#  'knowledge representation',
#  'language model',
#  'language modeling',
#  'large scale data',
#  'long short term memory',
#  'los function',
#  'los functions',
#  'lstm',
#  'machine intelligence',
#  'machine learning',
#  'machine translation',
#  'manipulator',
#  'markov decision',
#  'markov proce',
#  'massive data',
#  'meta learning',
#  'microsoft azure',
#  'ml',
#  'mlp',
#  'mobile robot',
#  'monte carlo',
#  'multi cloud',
#  'multilayer perceptron',
#  'natural language processing',
#  'nearest neighbour',
#  'neuromorphic computation',
#  'neuromorphic computer',
#  'neuromorphic computing',
#  'nlp',
#  'non relational database',
#  'nosql',
#  'object detection',
#  'object identification',
#  'object recognition',
#  'on demand computing',
#  'optical computing',
#  'oracle',
#  'paa',
#  'parallel processing',
#  'pattern recognition',
#  'policy gradient',
#  'pose estimation',
#  'principal component',
#  'q learning',
#  'quantum computation',
#  'quantum computer',
#  'quantum computing',
#  'random forest',
#  'recurrent neural network',
#  'regression',
#  'reinforcement learning',
#  'relational database',
#  'robot',
#  'robotic',
#  'saa',
#  'search algorithm',
#  'search tree',
#  'self driving',
#  'semantic search',
#  'semi supervised learning',
#  'sentiment analysi',
#  'seq2seq',
#  'spark',
#  'speech recognition',
#  'sql',
#  'statistical learning',
#  'supercomputer',
#  'supervised learning',
#  'support vector',
#  'svm',
#  'text classification',
#  'text to speech',
#  'topic modeling',
#  'transfer learning',
#  'transformer network',
#  'uav',
#  'ugv',
#  'underwater vehicle',
#  'unmanned aerial vehicle',
#  'unmanned air vehicle',
#  'unmanned aircraft',
#  'unmanned ground vehicle',
#  'unmanned underwater',
#  'unmanned vehicle',
#  'unsupervised learning',
#  'voice activity detection',
#  'voice recognition',
#  'word2vec'}

# %%
patents2['topics'] = map_topics(patents2['topics'], mapper)
unique_topics(patents2['topics'])
# Out:
# 103 topics
# {'3D Print',
#  'AI',
#  'AUV',
#  'AWS',
#  'Audio Classification',
#  'Auto Encoder',
#  'Autoencoder',
#  'Automated Reasoning',
#  'BD & Cloud Solutions',
#  'Back-propagation',
#  'Bayesian Inference',
#  'Big Data',
#  'Boltzmann Machine',
#  'Boosting',
#  'Chatbot',
#  'Classification',
#  'Clouds',
#  'Cluster Computing',
#  'Clustering',
#  'Computer Vision',
#  'Convolutional Networks',
#  'Data Center',
#  'Data Mining',
#  'Data Science',
#  'Data Storage',
#  'Database',
#  'Deep Learning',
#  'Dimensionality Reduction',
#  'Distributed Computing',
#  'Distributed File System',
#  'Dynamic Cloud',
#  'Dynamic Programming',
#  'Edge Computing',
#  'Encoder Decoder',
#  'Entity Recognition',
#  'Expert System',
#  'Face Detection',
#  'Feature Engineering',
#  'Feature Extraction',
#  'Fog Computing',
#  'Fully Connected Layer',
#  'GPU',
#  'Generative Adversarial Network',
#  'Genetic Algorithm',
#  'Gesture Recognition',
#  'Hardware Acceleration',
#  'High Performance Computing',
#  'Humanoid Robots',
#  'IaaS',
#  'Image Classification',
#  'Image Recognition',
#  'Image Segmentation',
#  'Information Retrieval',
#  'Knowledge Representation',
#  'Language Modeling',
#  'Loss Function',
#  'Loss Functions',
#  'Machine Learning',
#  'Machine Translation',
#  'Manipulator',
#  'Markov',
#  'Meta Learning',
#  'Mobile Robots',
#  'Monte Carlo',
#  'Multi-layer perceptron',
#  'NLP',
#  'NRDBMS & NoSQL',
#  'Nearest Neighbors',
#  'Neuromorphic Computing',
#  'Object Recognition',
#  'Optical Computing',
#  'Optimization Algorithm',
#  'PaaS',
#  'Parallel Processing',
#  'Pattern Recognition',
#  'Pose Estimation',
#  'Quantum Computing',
#  'RDBMS & SQL',
#  'RNN',
#  'Regression',
#  'Reinforcement Learning',
#  'Robotics',
#  'Robots',
#  'SVM',
#  'SaaS',
#  'Search Algorithm',
#  'Semantic Search',
#  'Semi Supervised Learning',
#  'Sentiment Analysis',
#  'Statistical Learning',
#  'Supercomputers',
#  'Supervised Learning',
#  'Text Classification',
#  'Text Embedding',
#  'Topic Modeling',
#  'Transfer Learning',
#  'Transformers & Attention',
#  'Trees',
#  'UAM',
#  'UGV',
#  'Unmanned Vehicle',
#  'Unsupervised Learning',
#  'Voice Recognition'}

# %%
patents2.to_csv('data/patents_topics2.csv', index=False)
patents2.head()
# Out:
#                     topics  year      date  \
# 0   UAM / Computer Vision   2020  20200917
# 1        Machine Learning   2020  20200903
# 2                      AI   2020  20200820
# 3                      AI   2020  20200811
# 4                      AI   2020  20200806
#
#                                             inventor  \
# 0  'GHIGLINO NOVOA, Pablo Francisco, ', 'BARBADIL...
# 1                  'WENZEL, FABIAN, ', 'BROSCH, TOM'
# 2         'ROYTMAN, Anatoly, ', 'Naressi, Alexandre'
# 3  'H.<U+5B54><U+6CFD>, ', 'P.<U+8D39><U+5E0C><U+...
# 4  'Kunze, Holger, ', 'Fischer, Peter, ', 'Kreher...
#
#                                            applicant country
# 0  'ALERION TECH S L 2002ES', 'ALERION TECHNOLOGI...      US
# 1  'KONINKLIJKE PHILIPS NV 2002NL', 'KONINKLIJKE ...      US
# 2  'ACCENTURE GLOBAL SERVICES LTD 2002IE', 'Accen...      US
# 3  'SIEMENS HEALTHCARE GMBH', '<U+897F><U+95E8><U...      CN
# 4  'SIEMENS HEALTHCARE GMBH 2002DE', 'Siemens Hea...      US

# %% [markdown]
# ## Data preparation

# %%
import pandas as pd

papers = pd.read_csv('data/papers_topics2.csv')
patents = pd.read_csv('data/patents_topics2.csv')

papers = papers[~(papers['research_areas'].isna() | papers.AU.isna())]

# %%
import numpy as np
import re

def count_topics(data, science=False):
    series = data["topics"]
    t = series.str.strip().str.split(' / ').tolist()
    t = pd.Series([x for y in t for x in y])
    vc, vcp = t.value_counts(), t.value_counts(normalize=True)
    d = pd.DataFrame({'count': vc, 'proportion': vcp})
    if science:
        d['citations'] = pd.Series(vc.index).\
                            apply(lambda key: data.loc[data["topics"].str.contains(key), "n_citations"].sum(skipna=True)).\
                            values
    return d

def strata_count(data, strata='year', datat='patents', string=False, rank=None):
    if string:
        col = strata
        strata = data[strata].str.split('; ').tolist()
        strata = set([x for y in strata for x in y])
        for stratum in strata:
            if stratum in rank.index: 
                ct = count_topics(data.loc[data[col].str.contains(stratum, regex=True)]) if datat=='patents' else \
                     count_topics(data.loc[data[col].str.contains(stratum, regex=True)], science=True)
                path = f"data/counts/{datat}_count_{col}_{rank[stratum] if rank is not None else 'a'}_" + \
                        re.sub('\W', '_', stratum) + ".csv"
                ct.to_csv(path, index_label="topic")
    else:
        for stratum in data[strata].unique():
            ct = count_topics(data.loc[data[strata] == stratum])if datat=='patents' else \
                 count_topics(data.loc[data[strata] == stratum], science=True)
            ct.to_csv(f"data/counts/{datat}_count_{strata}_{stratum}.csv", index_label="topic")

# %% [markdown]
# **Overall count**

# %%
count_topics(patents).to_csv('data/counts/patents_count.csv', index_label="topic")
count_topics(papers, science=True).to_csv('data/counts/papers_count.csv', index_label="topic")

# %% [markdown]
# **Count per year**

# %%
strata_count(patents, strata='year', datat='patents')
strata_count(papers, strata='year', datat='papers')

# %% [markdown]
# **Count per author**

# %%
patents.inventor = patents.inventor.str.split(", ', ").str.join("; ").str.replace("[',]", "", regex=True)
au = patents.inventor.str.split("; ").tolist()
au = pd.Series([x for y in au for x in y]).value_counts()[:50]
au = pd.Series(list(range(1, 51)), index=au.index)
pattern = '|'.join(au.index)

strata_count(patents[patents.inventor.str.contains(pattern, regex=True)], 
             strata='inventor', datat='patents', string=True, rank = au)

# %%
papers.AU = papers.AU.str.strip().str.replace(',', '',regex=True)
au = papers.AU.str.split('; ').tolist()
au = pd.Series([x for y in au for x in y]).value_counts()[:50]
au = pd.Series(list(range(1, 51)), index=au.index)
pattern = '|'.join(au.index)

strata_count(papers[papers.AU.str.contains(pattern, regex=True)], 
             strata='AU', datat='papers', string=True, rank = au)

# %% [markdown]
# **Count per Publisher (papers only)**

# %%
papers.publisher = papers.publisher.str.strip().str.replace('\W', ' ',regex=True)
pub = papers.publisher.str.split('; ').tolist()
pub = pd.Series([x for y in pub for x in y]).value_counts()[:50]
pub = pd.Series(list(range(1, 51)), index=pub.index)
pattern = '|'.join(pub.index)

strata_count(papers[papers.publisher.str.contains(pattern, regex=True)], 
             strata='publisher', datat='papers', string=True, rank = pub)

# %% [markdown]
# **Count per research area (papers only)**

# %%
def ra_count(data, rank, y):
    strata = data['research_areas'].str.split('\s{2,3}').tolist()
    strata = set([x for y in strata for x in y])
    ds = []
    for stratum in strata:
        d = data[data["research_areas"].str.contains(stratum)]
        t = d['topics'].str.strip().str.split(' / ').tolist()
        t = pd.Series([x for y in t for x in y])
        vc = t.value_counts()
        d = pd.DataFrame({'count': vc, 'ra': stratum, 'year': y})
        d['citations'] = pd.Series(vc.index).\
                            apply(lambda key: data.loc[data["topics"].str.contains(key), "n_citations"].sum(skipna=True)).\
                            values
        ds.append(d.reset_index())
    try:
        return pd.concat(ds)
    except:
        pass

# %%
papers.research_areas = papers.research_areas.str.strip().str.replace('\W', ' ',regex=True)
ra = papers.research_areas.str.split('\s{2,3}').tolist()
ra = pd.Series([x for y in ra for x in y]).value_counts()[:30]
ra = pd.Series(list(range(1, 31)), index=ra.index)
pattern = '|'.join(ra.index)

ds = []
for y in range(2000, 2022):
    d = ra_count(papers[(papers.year==y) & (papers.research_areas.str.contains(pattern, regex=True))], ra, y)
    ds.append(d)
res = pd.concat(ds).reset_index(drop=True)
res.columns = ['Topic', 'count', 'ScienceT', 'year', 'citations']
res.to_csv('data/counts/papers_RA.csv', index=False)
res
# Out:
#                    Topic  count             ScienceT  year  citations
# 0                     AI      5  Building Technology  2000      33238
# 1                 Robots      3  Building Technology  2000      12399
# 2               Robotics      2  Building Technology  2000       6934
# 3            Data Mining      1  Building Technology  2000       7278
# 4      Voice Recognition      1  Building Technology  2000       1859
# ...                  ...    ...                  ...   ...        ...
# 76539     Classification      1            Radiology  2021          8
# 76540           Big Data      1            Radiology  2021         16
# 76541     Classification      1     Nuclear Medicine  2021          8
# 76542           Big Data      1     Nuclear Medicine  2021         16
# 76543           Big Data      1         Architecture  2021         16
#
# [76544 rows x 5 columns]

# %% [markdown]
# ## Co-occurence matrix

# %%
import pandas as pd

papers = pd.read_csv('data/papers_topics2.csv')
patents = pd.read_csv('data/patents_topics2.csv')

# %%
import numpy as np
import itertools
from scipy.sparse import csr_matrix

def co_matrix(unique_topics, topics_list): 
    word_to_id = dict(zip(unique_topics, range(len(unique_topics))))
    documents_as_ids = [np.sort([word_to_id[w] for w in doc if w in word_to_id]).astype('uint32') for doc in topics_list]
    row_ind, col_ind = zip(*itertools.chain(*[[(i, w) for w in doc] for i, doc in enumerate(documents_as_ids)]))
    
    data = np.ones(len(row_ind), dtype='uint32')  
    max_word_id = max(itertools.chain(*documents_as_ids)) + 1
    
    docs_words_matrix = csr_matrix((data, (row_ind, col_ind)), shape=(len(documents_as_ids), max_word_id))  
    words_cooc_matrix = docs_words_matrix.T * docs_words_matrix 
    words_cooc_matrix.setdiag(0)
    
    return pd.DataFrame(words_cooc_matrix.todense(), index=unique_topics, columns=unique_topics)

# %% [markdown]
# **Industry**

# %%
topics_list = patents.topics.str.split("/").tolist()
unique_topics = set([x for y in topics_list for x in y])

cm = co_matrix(unique_topics, topics_list)
cm.to_csv("data/counts/patents_co_occ.csv", index_label="Topic")
cm.head()
# Out:
#                          Nearest Neighbors    BD & Cloud Solutions   \
#  Nearest Neighbors                        0                       0
#  BD & Cloud Solutions                     0                       0
#  Monte Carlo                              0                       0
#  Database                                 0                       8
#  Machine Translation                      0                       0
#
#                          Monte Carlo    Database    Machine Translation   \
#  Nearest Neighbors                  0           0                      0
#  BD & Cloud Solutions               0           8                      0
#  Monte Carlo                        0           0                      0
#  Database                           0           0                      1
#  Machine Translation                0           1                      0
#
#                          Knowledge Representation    AWS   \
#  Nearest Neighbors                               0      0
#  BD & Cloud Solutions                            0      2
#  Monte Carlo                                     0      0
#  Database                                        1      2
#  Machine Translation                             0      0
#
#                          Language Modeling    Supercomputers   \
#  Nearest Neighbors                        0                 0
#  BD & Cloud Solutions                     0                 0
#  Monte Carlo                              0                 0
#  Database                                 1                 0
#  Machine Translation                      4                 0
#
#                          Classification   ...   Computer Vision   \
#  Nearest Neighbors                     2  ...                  0
#  BD & Cloud Solutions                  0  ...                  0
#  Monte Carlo                           0  ...                  0
#  Database                             17  ...                  4
#  Machine Translation                   0  ...                  0
#
#                          Loss Functions    Data Science    IaaS   \
#  Nearest Neighbors                     0               0       0
#  BD & Cloud Solutions                  0               0       0
#  Monte Carlo                           0               0       0
#  Database                              0               0       0
#  Machine Translation                   0               0       0
#
#                          Data Mining    GPU    Image Segmentation    UGV   \
#  Nearest Neighbors                  2      0                     0      0
#  BD & Cloud Solutions               0      0                     0      0
#  Monte Carlo                        0      0                     0      0
#  Database                          20      0                     4      5
#  Machine Translation                0      0                     0      0
#
#                          Entity Recognition    Loss Function
#  Nearest Neighbors                         0                0
#  BD & Cloud Solutions                      0                0
#  Monte Carlo                               0                0
#  Database                                  0                1
#  Machine Translation                       0                0
#
# [5 rows x 103 columns]

# %%
for y in patents.year.unique():
    topics_list = patents.loc[patents.year == y, "topics"].str.split("/").tolist()
    unique_topics = set([x for y in topics_list for x in y])

    cm = co_matrix(unique_topics, topics_list)
    cm.to_csv(f"data/counts/patents_co_occ_{y}.csv", index_label="Topic")

# %% [markdown]
# **Science**

# %%
topics_list = papers.topics.str.split("/").tolist()
unique_topics = set([x for y in topics_list for x in y])

cm = co_matrix(unique_topics, topics_list)
cm.to_csv("data/counts/papers_co_occ.csv", index_label="Topic")
cm.head()
# Out:
#                          Multiprocessing    Nearest Neighbors   \
#  Multiprocessing                        0                    0
#  Nearest Neighbors                      0                    0
#  Autonomou Cars                         0                    0
#  BD & Cloud Solutions                   2                    4
#  Multi Processing                       1                    0
#
#                          Autonomou Cars    BD & Cloud Solutions   \
#  Multiprocessing                       0                       2
#  Nearest Neighbors                     0                       4
#  Autonomou Cars                        0                       0
#  BD & Cloud Solutions                  0                       0
#  Multi Processing                      0                       0
#
#                          Multi Processing    Industry 4 0    Monte Carlo   \
#  Multiprocessing                         1               0              0
#  Nearest Neighbors                       0               0              3
#  Autonomou Cars                          0               0              1
#  BD & Cloud Solutions                    0              23             14
#  Multi Processing                        0               0              0
#
#                          Database    Machine Translation   \
#  Multiprocessing                 1                      0
#  Nearest Neighbors              54                      0
#  Autonomou Cars                  0                      0
#  BD & Cloud Solutions          450                     10
#  Multi Processing                0                      0
#
#                          Knowledge Representation   ...   Computer Vision   \
#  Multiprocessing                                 2  ...                  1
#  Nearest Neighbors                               1  ...                 20
#  Autonomou Cars                                  0  ...                  1
#  BD & Cloud Solutions                           13  ...                 14
#  Multi Processing                                1  ...                  2
#
#                          Loss Functions    Data Science    IaaS   \
#  Multiprocessing                       0               0       0
#  Nearest Neighbors                     1               1       0
#  Autonomou Cars                        0               0       1
#  BD & Cloud Solutions                  3              35      73
#  Multi Processing                      0               0       0
#
#                          Data Mining    GPU    Image Segmentation    UGV   \
#  Multiprocessing                    1      2                     0      0
#  Nearest Neighbors                 68      0                    28      3
#  Autonomou Cars                     0      0                     0     11
#  BD & Cloud Solutions             232      5                    10      4
#  Multi Processing                   0      4                     3      0
#
#                          Entity Recognition    Loss Function
#  Multiprocessing                           0                0
#  Nearest Neighbors                         0                1
#  Autonomou Cars                            0                0
#  BD & Cloud Solutions                      4                3
#  Multi Processing                          0                0
#
# [5 rows x 133 columns]

# %%
for y in papers.year.unique():
    topics_list = papers.loc[papers.year == y, "topics"].str.split("/").tolist()
    unique_topics = set([x for y in topics_list for x in y])

    cm = co_matrix(unique_topics, topics_list)
    cm.to_csv(f"data/counts/papers_co_occ_{y}.csv", index_label="Topic")
